# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  20150428_collected_images.tgz	 climate_change_model   model-test
#  argumentative-creative-essays	'Colab Notebooks'       music
#  backup-dell			 data		        recipes

# %%
# !git clone https://TOKEN@github.com/SwathiKrishnaraja/argumentative-creative-essays

# %%
! ls argumentative-creative-essays
# Out:
#  Corpus-creative-essays-climate-change.csv
#  Corpus-creative-essays-sustainable-university.csv
# 'Corpus-creative-essays-veganism .csv'
#  README.md

# %%
import pandas as pd
df = pd.read_csv("argumentative-creative-essays/Corpus-creative-essays-climate-change.csv")
df.columns =['id', 'text']
print(len(df))
df.head(1)
# Out:
# 103
#                          id                                               text
# 0  5f19559b9665f700090276c4  Climate change is a globally relevant issue th...

# %% [markdown]
# ## Preprocess
# We split the esssays into sentences.

# %%
import itertools
print(len(df['text'].values))
docs_list = [df['text'][i].split(".") for i in range(len(df))]
our_docs = list(itertools.chain.from_iterable(docs_list))
len(our_docs)
# Out:
# 103
# 1266

# %% [markdown]
# We keep the sentences with more than one word. We are removing empty enters.

# %%
docs_filtered = [x for x in our_docs if len(x.split())>1]
len(docs_filtered)
# Out:
# 1146

# %% [markdown]
# ## Topic Modeling

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP

# Remove stop words from definition not from model
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")

# Seed the model
umap_model = UMAP(n_neighbors=10, n_components=5,
                  min_dist=0.0, metric='cosine', random_state=42)

topic_model = BERTopic(language="english",
                       min_topic_size = 10,
                       umap_model=umap_model,
                       vectorizer_model=vectorizer_model,
                       calculate_probabilities=True,
                       verbose=True)

# Fit the model with our data
topics, probs = topic_model.fit_transform(docs_filtered)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/36 [00:00<?, ?it/s]
# 2022-08-04 16:18:23,489 - BERTopic - Transformed documents to Embeddings
# 2022-08-04 16:18:33,240 - BERTopic - Reduced dimensionality
# 2022-08-04 16:18:33,345 - BERTopic - Clustered reduced embeddings

# %% [markdown]
# ### View results

# %%
topic_model.visualize_barchart(top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="afa2a980-60ff-4e71-8ca3-88b0b2342fcd" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afa2a980-60ff-4e71-8ca3-88b0b2342fcd")) {                    Plotly.newPlot(                        "afa2a980-60ff-4e71-8ca3-88b0b2342fcd",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03386738198091273,0.03643160936238374,0.043731545564668135,0.04432126801172361,0.04664745276398914],"y":["public transport  ","electric  ","cars  ","public  ","transport  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.022446492490711997,0.025417215696443465,0.02973482210822446,0.033349320621945504,0.05036512184855051],"y":["need  ","make  ","future  ","change  ","planet  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.05091013323819941,0.060731928586843745,0.07565691233917085,0.08450134899686786,0.09210422284850096],"y":["fight climate  ","fight  ","change  ","climate change  ","climate  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.03175797731639238,0.03646096467969032,0.04116841852438903,0.05590313384345589,0.08593987153455872],"y":["use  ","wind  ","renewable  ","solar  ","energy  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.032003933651284094,0.03282332799976742,0.039511785115817766,0.05830430149071702,0.09980961221010815],"y":["tree  ","planting  ","plant trees  ","plant  ","trees  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.029205035798464465,0.033559064572003805,0.052383242899998905,0.05471063273617377,0.056510935595718105],"y":["use  ","products  ","packaging  ","plastic  ","recycling  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.022885486643755913,0.025041049754645852,0.029716386545338442,0.030970121997547364,0.03169788990362164],"y":["big  ","environmental  ","companies  ","need  ","pollution  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.040936153738299445,0.04922940585276,0.05279857629563366,0.05694438335843694,0.05931822975049062],"y":["temperatures  ","climate change  ","weather  ","change  ","climate  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03361690481513583,0.042343875260296704,0.044696051268433304,0.05018942618472267,0.09015146569596019],"y":["carbon emissions  ","footprint  ","carbon footprint  ","emissions  ","carbon  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.05103888830365717,0.05112627208160942,0.05112627208160942,0.0648983204483486,0.1684544622560298],"y":["products  ","meat dairy  ","dairy products  ","dairy  ","meat  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.04742945431147897,0.056090801410521314,0.07943417220964284,0.082745552752983,0.08289427486397243],"y":["issue  ","problem  ","change  ","climate  ","climate change  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.04892603215543906,0.0555074117671593,0.06089862742095213,0.07468010168677124,0.10940399122927537],"y":["thermostat  ","home  ","heat  ","degrees  ","insulation  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.047146903713423095,0.05757156930034728,0.08821873207126575,0.09224745624104808,0.14208289905908503],"y":["showers  ","use hot  ","hot  ","hot water  ","water  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{ ...

# %%
topic_model.visualize_distribution(probs[200], min_probability=0.015)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="05b342e7-ca6f-44af-9796-fec7a59127d3" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05b342e7-ca6f-44af-9796-fec7a59127d3")) {                    Plotly.newPlot(                        "05b342e7-ca6f-44af-9796-fec7a59127d3",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.08469889209367379,0.030053947012181347,0.03603585642484061,0.23537667373815632,0.03115970030208334,0.035397484706517164,0.05699217385803569,0.020117103307313016,0.13551681751885386,0.03290961546178628,0.025455209515395524,0.06499510575817304,0.039013653419976785,0.06980691017598155,0.033406460613235156,0.03500098678808045,0.034063409305716164],"y":["<b>Topic 0</b>: transport_public_cars_el...","<b>Topic 1</b>: planet_change_future_mak...","<b>Topic 2</b>: climate_climate change_c...","<b>Topic 3</b>: energy_solar_renewable_w...","<b>Topic 4</b>: trees_plant_plant trees_...","<b>Topic 5</b>: recycling_plastic_packag...","<b>Topic 6</b>: pollution_need_companies...","<b>Topic 7</b>: climate_change_weather_c...","<b>Topic 8</b>: carbon_emissions_carbon ...","<b>Topic 9</b>: meat_dairy_dairy product...","<b>Topic 10</b>: climate change_climate_...","<b>Topic 11</b>: insulation_degrees_heat...","<b>Topic 12</b>: water_hot water_hot_use...","<b>Topic 13</b>: lights_turn_devices_led...","<b>Topic 14</b>: clothes_buy_old clothes...","<b>Topic 15</b>: plant based_based_plant...","<b>Topic 16</b>: food_waste_food waste_l..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36 ...

# %%
topic_model.visualize_heatmap(n_clusters=None, width=1000, height=1000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="04e192cb-3ea7-43eb-94b5-cbab1bf7c083" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04e192cb-3ea7-43eb-94b5-cbab1bf7c083")) {                    Plotly.newPlot(                        "04e192cb-3ea7-43eb-94b5-cbab1bf7c083",                        [{"coloraxis":"coloraxis","name":"0","x":["0_transport_public_cars","1_planet_change_future","2_climate_climate change_ch...","3_energy_solar_renewable","4_trees_plant_plant trees","5_recycling_plastic_packaging","6_pollution_need_companies","7_climate_change_weather","8_carbon_emissions_carbon f...","9_meat_dairy_dairy products","10_climate change_climate_c...","11_insulation_degrees_heat","12_water_hot water_hot","13_lights_turn_devices","14_clothes_buy_old clothes","15_plant based_based_plantb...","16_food_waste_food waste"],"y":["0_transport_public_cars","1_planet_change_future","2_climate_climate change_ch...","3_energy_solar_renewable","
# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def preprocess(text):
  sentences = text.split('.')
  sentences = [x for x in sentences if len(x.split())>1]
  return sentences


def get_fluency(preds_model, pred_topics):
  """
  The general idea is to sum up the ‘effort’ that each topic represents, which is expressed as the distance of each topic to zero. If you just count, the assumption is that the effort of each topic is 1.

  Returns: Value between 0 and 1
  1 means that the user wrote about ALL the topics
  0 the user did not write about any of the topics
  """
  list_topics = list(np.unique(pred_topics))
  # -1 are outliers
  found_topics = [x for x in list_topics if x>-1]
  all_topics = preds_model.get_topics()
  fluency = len(found_topics)/len(all_topics)
  return found_topics, fluency


def compute_flexibility(found_topics, similarity_matrix):
  """
  Range 0-1. Where 1 is that they are very distant and 0 that they are very close
  Greater is best

  If there is only one element it will return zero
  """
  global_similarity = 0


  if len(found_topics)>1:
    for i in found_topics:
      other_topics = [x for x in found_topics if x != i]
      topic_similarity = 0
      for j in other_topics:
        topic_similarity +=  similarity_matrix[i,j]

      topic_similarity = topic_similarity/len(other_topics)
      global_similarity += topic_similarity/len(found_topics)
  else:
    global_similarity = 1


  return 1 - global_similarity


def get_flexibility(preds_model, found_topics):
  """
  Average pairwise distance between all user topics
  """
  embeddings = np.array(preds_model.topic_embeddings)

  # remove -1 (outliers)
  embeddings = embeddings[1:]

  similarity_matrix = cosine_similarity(embeddings)
  flexibility = compute_flexibility(found_topics, similarity_matrix)
  return flexibility

def get_originality(pred_topics):
  """
  How many were outliers TBD
  """
  originality = pred_topics.count(-1)/len(pred_topics)
  return originality


climate_model = BERTopic.load("climate_change_model")

## MAIN
def get_metrics(text, dataset = "climate_change"):
  if dataset == "climate_change":
    preds_model = climate_model
  sentences = preprocess(text)
  pred_topics, pred_prob = preds_model.transform(sentences)
  found_topics, fluency = get_fluency(preds_model, pred_topics)
  flexibility = get_flexibility(preds_model, found_topics)
  originality = get_originality(pred_topics)
  return fluency, flexibility, originality

# %%
### Tests
text = df['text'].iloc[0]
get_metrics(text)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2022-08-04 16:20:27,118 - BERTopic - Reduced dimensionality
# 2022-08-04 16:20:27,127 - BERTopic - Calculated probabilities with HDBSCAN
# 2022-08-04 16:20:27,129 - BERTopic - Predicted clusters
# (0.3333333333333333, 0.4809730223597357, 0.26666666666666666)

# %%
text  = """
The shoelace formula, shoelace algorithm, or shoelace method (also known as Gauss's area formula and the surveyor's formula)[1] is a mathematical algorithm to determine the area of a simple polygon whose vertices are described by their Cartesian coordinates in the plane.[2] It is called the shoelace formula because of the constant cross-multiplying for the coordinates making up the polygon, like threading shoelaces.[2] It has applications in surveying and forestry,[3] among other areas.
The formula was described by Albrecht Ludwig Friedrich Meister (1724–1788) in 1769[4] and is based on the trapezoid formula which was described by Carl Friedrich Gauss and C.G.J. Jacobi.[5] The triangle form of the area formula can be considered to be a special case of Green's theorem.
The area formula can also be applied to self-overlapping polygons since the meaning of area is still clear even though self-overlapping polygons are not generally simple.[6] Furthermore, a self-overlapping polygon can have multiple "interpretations" but the Shoelace formula can be used to show that the polygon's area is the same regardless of the interpretation.[7]
"""
get_metrics(text)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2022-08-04 16:20:27,985 - BERTopic - Reduced dimensionality
# 2022-08-04 16:20:27,992 - BERTopic - Calculated probabilities with HDBSCAN
# 2022-08-04 16:20:27,994 - BERTopic - Predicted clusters
# (0.05555555555555555, 0, 0.5714285714285714)
